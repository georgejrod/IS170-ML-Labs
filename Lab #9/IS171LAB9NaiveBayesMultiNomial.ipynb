# %%
import pandas as pd
from sklearn.naive_bayes import MultinomialNB       # The Naive Bayes model
from sklearn.feature_extraction.text import CountVectorizer  # Turns words into numbers
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("email.csv")
#using pandas to import dataset

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
emails = df['Message']
#taking the emails out of the messages column and giveing it a label using pandas df

# %%
le = LabelEncoder()
labels = le.fit_transform(df['Category'])
print(labels[:5])
#encoding category column and turning into numerical data, labeling SPAM as 1 and HAM as 0
# Out:
# [0 0 1 0 0]

# %%
vectorizer = CountVectorizer()

X = vectorizer.fit_transform(emails)
probabilities = model.predict_proba(X_new)
predictions = model.predict(X_new)
#fits and transforms email column into numerical data
#learns unique words and then converts to a number list

# %%
print(f"All unique words found {len(vectorizer.get_feature_names_out())}")
#total unique words found with the vectorizer
# Out:
# All unique words found 8711

# %%
model = MultinomialNB()
model.fit(X, labels)
#fitting model, with X being the transformed emails and labels being the classification of the training dataset
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
y_pred = model.predict(X)

print(f"Accuracy: {accuracy_score(labels, y_pred):.4f}")
print(f"Precision: {precision_score(labels, y_pred, average='weighted'):.4f}")
print(f"Recall: {recall_score(labels, y_pred, average='weighted'):.4f}")
print(f"F1 Score: {f1_score(labels, y_pred, average='weighted'):.4f}")

print("\nClassification Report:")
print(classification_report(labels, y_pred))
#prints a classification report with precision, recall, f1-score, and support
# Out:
# Accuracy: 0.9923
# Precision: 0.9932
# Recall: 0.9923
# F1 Score: 0.9927
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4825
#            1       0.98      0.97      0.98       747
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.99      5573
#    macro avg       0.66      0.66      0.66      5573
# weighted avg       0.99      0.99      0.99      5573

# %%
new_email = input("Enter example email: ")
X_new = vectorizer.transform([new_email])
predictions = model.predict(X_new)
probabilities = model.predict_proba(X_new)
#user input for a new email
#user must design an email that is intended to be normal or spam
# Out:
# Enter example email: Offering vacation packages at low rate! Click here to enter to win 100$ in sweepstakes!

# %%
result = "SPAM" if predictions[0] == 1 else "NOT SPAM"
prob_spam = probabilities[0][1] * 100
prob_notspam = probabilities[0][0] * 100
print(f"Email: '{new_email}'")
print(f"  --> Prediction : {result}")
print(f"  --> Spam chance: {prob_spam:.1f}%")
print(f"  --> Ham  chance: {prob_notspam:.1f}%")
print()
#gets probability metric for predictions made on new user generated email.
# Out:
# Email: 'Offering vacation packages at low rate! Click here to enter to win 100$ in sweepstakes!'
#   --> Prediction : SPAM
#   --> Spam chance: 100.0%
#   --> Ham  chance: 0.0%

# %% [markdown]
# This model takes examples of "ham" and "spam" emails and trains a naive bayes multinomial model to predict whether a user inputted email is spam. This could be extremely useful, as spam is a dangerous aspect of using email services. With this model, each email coming into a users inbox can be checked and accurately classified as spam if it is malicous. The service provider can then filter these spam emails out and stop them from reaching the users inbox.
