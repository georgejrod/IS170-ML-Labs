# %% [markdown]
# Swati
#
# Decision Tree
#
# STROKE DATASET

# %%
# IS 140 Lab 6 – Decision Tree (Stroke Dataset)
# File: healthcare-dataset-stroke-data.csv
# Target: stroke (0/1)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
from google.colab import files #importing a file from local disk to google colab cloud/code
files.upload() #textbox and action button to upload file; upon uploading, file is displayed
# Out:
#      <input type="file" id="files-2686f23a-9f45-4844-8fec-fe1c420c64ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2686f23a-9f45-4844-8fec-fe1c420c64ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Basic Cleaning

#Drop the ID column
if "id" in df.columns:
    df = df.drop("id", axis=1)

# Fill missing BMI with median
# (Decision Trees cannot handle missing values)
df["bmi"] = df["bmi"].fillna(df["bmi"].median())

# %%
#Convert Categorical Variable

#Convert text categories into dummy/one-hot column
# drop_first=True prevents duplicate columns
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
# Split into features (X) and target (y)

#70% for training, 30% for testing
# stratify=y keeps class proportions balanced
x= df_encoded.drop('stroke', axis=1)
y= df_encoded['stroke']

# %%
# Train/ Test Split

# Create Decision Tree classifier object
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.30,
    random_state=1,
    stratify=y
)

# %%
# Train Descision Tree model

from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=1)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# Predict + evaluate

y_pred = dt_model.predict(X_test)

print("Accuracy:" , metrics.accuracy_score(y_test, y_pred))
print("\n Classification Report:\n")
print

# %%
# Visualize the Decision Tree

from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(
    dt_model,
    out_file=dot_data,
    filled=True,
    rounded=True,
    special_characters=True,
    feature_names=x.columns,
    class_names=["No Stroke","Stroke"]
)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# <div><p class="MuiTypography-root MuiTypography-bodyMedium MuiTypography-paragraph css-14g3j2x">Decision Tree Model Summary</p><p class="MuiTypography-root MuiTypography-bodyMedium MuiTypography-paragraph css-14g3j2x">In this lab, a Decision Tree classification model was developed to predict the probability of stroke using a healthcare dataset. The dataset contained demographic and health-related features, including age, hypertension, heart disease, glucose level, BMI, and smoking status. Following data cleaning and the conversion of categorical variables to numerical values, the dataset was split into training and testing subsets.</p></div>
#
# <p class="MuiTypography-root MuiTypography-bodyMedium MuiTypography-paragraph css-14g3j2x">The Decision Tree model was trained on 70% of the data and tested on the remaining 30%. It predicted stroke risk, and its performance was assessed using accuracy, a confusion matrix, and a classification report. The findings highlight how machine learning methods like decision trees can effectively analyze healthcare data and pinpoint potential stroke risk factors. This approach can assist medical professionals in making informed, data-driven decisions and enhancing the early identification of high-risk patients.</p>
